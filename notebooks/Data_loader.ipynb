# %%
import pandas as pd

df = pd.read_csv('../data/MergedData.csv')

# Print the head of the dataframe
print("Head of the data:")
print(df.head())

# Print the column names
print("\nColumn names:")
print(df.columns.tolist())

# Print unique values for the 'crime' column (assuming the column is named 'crime')
if 'crime' in df.columns:
    print("\nUnique values in 'crime' column:")
    print(df['crime'].unique())
else:
    print("\nNo 'crime' column found in the data.")

# Print the size of the data
print(f"\nShape of the data: {df.shape}")

# Print data types and non-null counts
print("\nData info:")
print(df.info())

# Print summary statistics for numeric columns
print("\nSummary statistics:")
print(df.describe())
# Out:
# Head of the data:
#              crime    datetime        date   time  district     dataset  \
# 0  weapons offense  2003-01-01  2003-01-01  19:04      PARK  historical
# 1    larceny theft  2003-01-01  2003-01-01  14:00  SOUTHERN  historical
# 2          robbery  2003-01-01  2003-01-01  13:05  SOUTHERN  historical
# 3          assault  2003-01-01  2003-01-01  00:01   MISSION  historical
# 4            fraud  2003-01-01  2003-01-01  14:39  SOUTHERN  historical
#
#     latitude   longitude  year  month
# 0  37.773156 -122.445087  2003      1
# 1  37.793941 -122.395616  2003      1
# 2  37.781751 -122.411071  2003      1
# 3  37.763099 -122.407808  2003      1
# 4  37.783588 -122.405493  2003      1
#
# Column names:
# ['crime', 'datetime', 'date', 'time', 'district', 'dataset', 'latitude', 'longitude', 'year', 'month']
#
# Unique values in 'crime' column:
# <StringArray>
# [    'weapons offense',       'larceny theft',             'robbery',
#              'assault',               'fraud',        'drug offense',
#            'vandalism',            'burglary', 'motor vehicle theft',
#       'missing person',  'disorderly conduct',        'prostitution',
#             'gambling']
# Length: 13, dtype: str
#
# Shape of the data: (1708893, 10)
#
# Data info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1708893 entries, 0 to 1708892
# Data columns (total 10 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   crime      str
#  1   datetime   str
#  2   date       str
#  3   time       str
#  4   district   str
#  5   dataset    str
#  6   latitude   float64
#  7   longitude  float64
#  8   year       int64
#  9   month      int64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 130.4 MB
# None
#
# Summary statistics:
#            latitude     longitude          year         month
# count  1.681719e+06  1.681719e+06  1.708893e+06  1.708893e+06
# mean   3.777041e+01 -1.224239e+02  2.014044e+03  6.538189e+00
# std    2.942042e-01  2.809244e-02  6.550237e+00  3.439685e+00
# min    3.770785e+01 -1.225136e+02  2.003000e+03  1.000000e+00
# 25%    3.775462e+01 -1.224345e+02  2.008000e+03  4.000000e+00
# 50%    3.777542e+01 -1.224177e+02  2.014000e+03  7.000000e+00
# 75%    3.778541e+01 -1.224072e+02  2.020000e+03  1.000000e+01
# max    9.000000e+01 -1.205000e+02  2.026000e+03  1.200000e+01
